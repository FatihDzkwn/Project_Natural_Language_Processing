# %% [markdown]
# # **1. Data Collection**

# %% [markdown]
# - Case Folding

# %% [markdown]
# *   Tokenization

# %% [markdown]
# *   Stop Word Removal

# %% [markdown]
# *   Stemming

# %% [markdown]
# # **3. Feature Extraction**

# %% [markdown]
# # **4. Modeling**

# %% [markdown]
# # **5. Comparison Model**
